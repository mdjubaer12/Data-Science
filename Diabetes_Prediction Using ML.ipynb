# %% [markdown]
# # **Implementing Using Decision Trees**

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 
import sklearn.tree as tree 
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
import scipy.optimize as opt
from sklearn import preprocessing
# Out:
# Error: Canceled future for execute_request message before replies were done
# at t.KernelShellFutureHandler.dispose (c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1204175)
# at c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1223227
# at Map.forEach (<anonymous>)
# at v._clearKernelState (c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1223212)
# at v.dispose (c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1216694)
# at c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:533674
# at t.swallowExceptions (c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:913059)
# at dispose (c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:533652)
# at t.RawSession.dispose (c:\Users\Aristo_NPC\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:537330)
# at processTicksAndRejections (node:internal/process/task_queues:96:5)

# %%
data= pd.read_csv("/content/diabetes.csv")
d=data
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Getting the shape of the Dataset and the name of the columns
print(data.shape)
data.columns
# Out:
# (768, 9)
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# **Data Pre-processing**

# %%
# Splitting Into Features and Target variables
X= data.iloc[:, :-1]
Y=data.iloc[:, -1]
print(np.shape(X))
np.shape(Y)
# Out:
# (768, 8)
# (768,)

# %%
# Splitting Into Tarin and Test Dataset

X_trainset, X_testset, Y_trainset, Y_testset = train_test_split(X, Y, test_size = 0.2, random_state=3)

# %%
# Getting The Shape of Train and Test Dataset
print('Shape of X training set {}'.format(X_trainset.shape),'&',' Size of Y training set {}'.format(Y_trainset.shape))
print('Shape of X test set {}'.format(X_testset.shape),'&',' Size of Y Test set {}'.format(Y_testset.shape))
# Out:
# Shape of X training set (614, 8) &  Size of Y training set (614,)
# Shape of X test set (154, 8) &  Size of Y Test set (154,)

# %% [markdown]
# **Now Build the Decision Tree Model**

# %%
DiabetesTree= DecisionTreeClassifier(criterion="entropy", max_depth=5)
DiabetesTree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
DiabetesTree.fit(X_trainset, Y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
pre= DiabetesTree.predict([[10,	65,	43,	12,	0,	22,	0.25, 0]])
print(pre)
# Out:
# [0]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %% [markdown]
# **Make The prediction**

# %%
pred= DiabetesTree.predict(X_testset)

# %%
# Checking The Prediction
print(pred[0:5])
print(Y_testset[0:5])
# Out:
# [0 1 0 1 0]
# 51     0
# 378    1
# 27     0
# 579    1
# 86     0
# Name: Outcome, dtype: int64

# %% [markdown]
# **Calculating The Accuracy**

# %%
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(Y_testset, pred))
# Out:
# DecisionTrees's Accuracy:  0.7207792207792207

# %% [markdown]
# **Plotting The Tree**

# %%
fig = plt.figure(figsize=(60,40))
tree.plot_tree(DiabetesTree, feature_names=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'], class_names=['0','1'], filled=True)
plt.show()

# %% [markdown]
# # **Random Forest Modeling**

# %%
Random_Forest= RandomForestClassifier(n_estimators = 200)
Random_Forest.fit(X_trainset, Y_trainset)
# Out:
# RandomForestClassifier(n_estimators=200)

# %% [markdown]
# **Predicting**

# %%
prediction= Random_Forest.predict(X_testset)

# %%
# Checking the prediction
print(prediction[0:5])
print(Y_testset[0:5])
# Out:
# [0 1 0 1 0]
# 51     0
# 378    1
# 27     0
# 579    1
# 86     0
# Name: Outcome, dtype: int64

# %% [markdown]
# **Accuarcy**

# %%
print("Random Forest Accuracy: ", metrics.accuracy_score(Y_testset, prediction))
# Out:
# Random Forest Accuracy:  0.7532467532467533

# %% [markdown]
# # **SVM**

# %%
from sklearn import svm
Dia_SVM=svm.SVC(kernel='linear')
Dia_SVM.fit(X_trainset, Y_trainset)
# Out:
# SVC(kernel='linear')

# %%
# Predicting Using Test set
y_hat=Dia_SVM.predict(X_testset)
print(y_hat[0:10])
print(Y_testset[0:10])
# Out:
# [0 1 0 1 0 1 0 0 0 0]
# 51     0
# 378    1
# 27     0
# 579    1
# 86     0
# 144    0
# 65     0
# 617    0
# 10     0
# 522    0
# Name: Outcome, dtype: int64

# %% [markdown]
# **Accuracy Testing**

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_testset, y_hat)
# Out:
# 0.7272727272727273
